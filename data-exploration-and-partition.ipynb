# %% [markdown]
# # Data exploration and descriptive statistics of satellite imagery
#
# This jupyter notebook will parse, collate and analyze satellite imagery files from Maxar (former DigitalGlobe) The parsing of the metadata files (`DeliveryMetadata.xml`) are mainly general and should work for any Maxar product delivery. After parsing of the metadata files into pandas dataframes the code is mainly project specific.

# %% [markdown]
# ## Imports and setup

# %%
import numpy as np
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import pathlib
import geopandas
import pickle

import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots

from modules.metadata_reader import img_metadata_to_dict, add_names_to_metadata_dict, dict_to_df

# Path to location where individual satellite images are located
DATA_PATH = 'data/toulon-laspezia' 
DATA_PATH_IS_RELATIVE = True
DATA_PATH_TILES = 'data/toulon-laspezia-tiles'

# Name of metadata .xml file
METADATA_NAME = 'DeliveryMetadata.xml'

# Names of areas covered by satellite imagery
AREAS = ['La_Spezia', 'Toulon'] # Spelled like the directory names

# Speficy what the xmlns url on top of metadata .xml file is
# (should be second line)
XMLNS = 'http://xsd.digitalglobe.com/xsd/dm'

# pandas options
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
#pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Metadata parsing from xml to pandas dataframe
#
# Every satellite image delivery from Maxar contains a `DeliveryMetadata.xml` file with important specifications for both the multispectral and panchromatic images. The following functions finds all the `DeliveryMetadata.xml` files contained in all subdirectories of a directory and parses them into the *Pandas DataFrame* format which will be used for further descriptive statistics of the dataset.

# %%
img_metadata_pan, img_metadata_ms = img_metadata_to_dict(METADATA_NAME, 
                                                         DATA_PATH, XMLNS, 
                                                         path_is_relative = DATA_PATH_IS_RELATIVE)

img_metadata_pan = add_names_to_metadata_dict(img_metadata_pan, AREAS)
img_metadata_ms = add_names_to_metadata_dict(img_metadata_ms, AREAS)

img_metadata_pan = dict_to_df(img_metadata_pan)
img_metadata_ms = dict_to_df(img_metadata_ms)

# Checking that string IDs and int IDs are equal in both dataframes (they should)
assert all(img_metadata_ms.index == img_metadata_pan.index)
assert all(img_metadata_ms['int_uid'] == img_metadata_pan['int_uid'])

# %% [markdown]
# ## Number of images

# %%
print('Number of panchromatic images:', len(img_metadata_pan))
print('Number of multispectral images:', len(img_metadata_ms), '\n')
if list(img_metadata_pan.index.values) == list(img_metadata_ms.index.values):
    print('Pass: Identical keys. Keys in panchromatic and multispectral dictionaries are identical.')
else: print('Fail: Identical keys. Keys in panchromatic and multispectral dictionaries are not identical.')
# Out:
# Number of panchromatic images: 73
# Number of multispectral images: 73
#
# Pass: Identical keys. Keys in panchromatic and multispectral dictionaries are identical.

# %% [markdown]
# ## Cleanup and merging of the two dataframes
#
# It is cumbersome to work with two almost identical dataframes so we will merge them and in the process remove quite a number of columns with redundant or irrelevant information.

# %%
def merge_metadata(metadata_df_pan, metadata_df_ms):
    
    # Starting with the panchromatic metadata dataframe
    df = metadata_df_pan.copy(deep = True)
    
    # Dropping the voluminous product columns. 
    # These contain paths and metadata to/of all files, but 90% of the files are not used
    # and it is often a better strategy to look up files by 'glob' or similar functions
    product_columns = df.columns[29:62].to_list()
    #print(product_columns)
    df.drop(columns = product_columns, inplace = True)
    
    # Dropping other columns
    df.drop(columns = 
           ['band0',             # Redundant since it simply states 'Pan' for all rows
            'cloudCover',        # The estimate is of very poor quality
            'imageTypeSize',     # This value looks to be wrong as it is equal for all images
            'imagingTilingType', # Not relevant info
            'isMosaic',          # This seems wrong as no images are mosaics of several images
            'mergingAlgorithm',  # Redundant since there is no band merging going on
            'mergedBand',        # Redundant since there is no band merging going on
            'strip0',            # A lot of duplicate info in this column
            'n_bands',           # Redundant as this is always 1 for Pan
            'n_products',        # Not relevant info
            'n_strips',          # Redundant as this is always 1 as no images are 
            'lineNumber',        # Not relevant info
            'incrementNumber'    # Not relevant info
           ], inplace = True)
    
    # Checking whether earliest and latest are equal. If they are only one of the columns
    # is needed and thus they are merged.
    if df['earliestAcquisitionTime'].equals(df['latestAcquisitionTime']):
        df.drop(columns = 'latestAcquisitionTime', inplace = True)
        df.rename(columns = {'earliestAcquisitionTime': 'acquisitionTime'}, 
                  inplace = True)
    else:
        print('Columns earliestAcquisitionTime and latestAcquisitionTime are not equal. Keeping both.')
    
    # Renaming columns to prepare for merging with the multispectral dataframe.
    df.rename(columns = 
              {'catalogIdentifier': 'pan_catalogIdentifier', 
               'processedProductId': 'pan_processedProductId', 
               'pixelHeight': 'pan_pixelHeight', 
               'pixelWidth': 'pan_pixelWidth', 
               'tif_path' : 'pan_tif_path'}, inplace = True)
    
    # Adding the relevant columns from the multispectral metadata dataframe
    df['ms_catalogIdentifier'] = metadata_df_ms['catalogIdentifier']
    df['ms_processedProductId'] = metadata_df_ms['processedProductId']
    df['ms_pixelHeight'] = metadata_df_ms['pixelHeight']
    df['ms_pixelWidth'] = metadata_df_ms['pixelWidth']
    df['ms_tif_path'] = metadata_df_ms['tif_path']
    df['ms_n_bands'] = metadata_df_ms['n_bands']
    df['ms_band0'] = metadata_df_ms['band0']
    df['ms_band1'] = metadata_df_ms['band1']
    df['ms_band2'] = metadata_df_ms['band2']
    df['ms_band3'] = metadata_df_ms['band3']
    df['ms_band4'] = metadata_df_ms['band4']
    df['ms_band5'] = metadata_df_ms['band5']
    df['ms_band6'] = metadata_df_ms['band6']
    df['ms_band7'] = metadata_df_ms['band7']

    # Reordering the columns for a more intuitive viewing experience
    columns_order = ['int_uid', 
                     'area_name',
                     'sensorVehicle', 
                     'pan_catalogIdentifier', 
                     'ms_catalogIdentifier', 
                     'pan_processedProductId', 
                     'ms_processedProductId',
                     'orderNumber', 
                     'acquisitionTime', 
                     'productionDate', 
                     'updateDate',
                     'bitsPerPixel', 
                     'imageFileFormat', 
                     'pan_pixelHeight', 
                     'pan_pixelWidth', 
                     'ms_pixelHeight', 
                     'ms_pixelWidth', 
                     'isDynamicRangeAdjusted', 
                     'processingLevel', 
                     'resamplingKernel', 
                     'datum', 
                     'mapProjection', 
                     'mapProjectionZone', 
                     'mapProjectionUnit',
                     'offNadirAngle', 
                     'sunAzimuth', 
                     'sunElevation', 
                     'ms_n_bands',
                     'ms_band0', 'ms_band1', 'ms_band2', 'ms_band3', 
                     'ms_band4', 'ms_band5', 'ms_band6', 'ms_band7',
                     'pan_tif_path', 
                     'ms_tif_path'
                    ]
    df = df.reindex(columns = columns_order)
    
    return df

meta = merge_metadata(img_metadata_pan, img_metadata_ms)

# %%
meta
# Out:
#                                             int_uid  area_name sensorVehicle  \
# GE01_La_Spezia_2009_09_25_011651186010_0          0  La_Spezia          GE01
# GE01_La_Spezia_2011_01_24_011651197010_0          1  La_Spezia          GE01
# GE01_La_Spezia_2012_02_23_011651192010_0          2  La_Spezia          GE01
# GE01_La_Spezia_2012_05_07_011651189010_0          3  La_Spezia          GE01
# GE01_La_Spezia_2012_05_16_011651187010_0          4  La_Spezia          GE01
# GE01_La_Spezia_2013_07_07_011651184010_0          5  La_Spezia          GE01
# GE01_La_Spezia_2013_07_15_011651183010_0          6  La_Spezia          GE01
# GE01_La_Spezia_2013_07_18_011651195010_0          7  La_Spezia          GE01
# GE01_La_Spezia_2013_07_23_011651202010_0          8  La_Spezia          GE01
# GE01_La_Spezia_2017_04_16_011651188010_0          9  La_Spezia          GE01
# GE01_La_Spezia_2019_01_03_011651196010_0         10  La_Spezia          GE01
# GE01_Toulon 2009_03_23_011651190010_0            11     Toulon          GE01
# GE01_Toulon 2010_06_08_011651191010_0            12     Toulon          GE01
# GE01_Toulon 2013_08_20_011651198010_0            13     Toulon          GE01
# GE01_Toulon 2014_10_16_011651185010_0            14     Toulon          GE01
# GE01_Toulon 2016_03_26_011651193010_0            15     Toulon          GE01
# GE01_Toulon 2016_09_21_011651200010_0            16     Toulon          GE01
# GE01_Toulon 2017_09_05_011651201010_0            17     Toulon          GE01
# GE01_Toulon 2018_02_13_011651199010_0            18     Toulon          GE01
# GE01_Toulon 2019_10_07_011651194010_0            19     Toulon          GE01
# WV02_La_Spezia_2010_08_06_011650744010_0         20  La_Spezia          WV02
# WV02_La_Spezia_2011_05_02_011650586010_0         21  La_Spezia          WV02
# WV02_La_Spezia_2011_05_10_011650587010_0         22  La_Spezia          WV02
# WV02_La_Spezia_2011_10_28_011650745010_0         23  La_Spezia          WV02
# WV02_La_Spezia_2012_01_10_011650582010_0         24  La_Spezia          WV02
# WV02_La_Spezia_2012_05_17_011650585010_0         25  La_Spezia          WV02
# WV02_La_Spezia_2013_10_31_011650588010_0         26  La_Spezia          WV02
# WV02_La_Spezia_2013_12_08_011650589010_0         27  La_Spezia          WV02
# WV02_La_Spezia_2014_11_20_011650595010_0         28  La_Spezia          WV02
# WV02_La_Spezia_2015_01_05_011650746010_0         29  La_Spezia          WV02
# WV02_La_Spezia_2015_03_19_011650598010_0         30  La_Spezia          WV02
# WV02_La_Spezia_2015_03_19_011650600010_0         31  La_Spezia          WV02
# WV02_La_Spezia_2015_04_24_011650748010_0         32  La_Spezia          WV02
# WV02_La_Spezia_2015_05_21_011650592010_0         33  La_Spezia          WV02
# WV02_La_Spezia_2017_03_10_011650750010_0         34  La_Spezia          WV02
# WV02_La_Spezia_2017_07_31_011650593010_0         35  La_Spezia          WV02
# WV02_La_Spezia_2018_05_18_011650597010_0         36  La_Spezia          WV02
# WV02_La_Spezia_2018_05_29_011650583010_0         37  La_Spezia          WV02
# WV02_La_Spezia_2018_07_06_011650749010_0         38  La_Spezia          WV02
# WV02_La_Spezia_2019_05_23_011650590010_0         39  La_Spezia          WV02
# WV02_La_Spezia_2019_06_03_011650596010_0         40  La_Spezia          WV02
# WV02_La_Spezia_2019_10_11_011650594010_0         41  La_Spezia          WV02
# WV02_Toulon_2010_11_04_011651051010_0            42     Toulon          WV02
# WV02_Toulon_2011_05_04_011651058010_0            43     Toulon          WV02
# WV02_Toulon_2011_12_22_011651063010_0            44     Toulon          WV02
# WV02_Toulon_2013_03_16_011651062010_0            45     Toulon          WV02
# WV02_Toulon_2013_04_07_011651056010_0            46     Toulon          WV02
# WV02_Toulon_2013_04_10_011651050010_0            47     Toulon          WV02
# WV02_Toulon_2013_10_09_011651061010_0            48     Toulon          WV02
# WV02_Toulon_2014_04_06_011651052010_0            49     Toulon          WV02
# WV02_Toulon_2015_11_16_011651049010_0            50     Toulon          WV02
# WV02_Toulon_2016_03_14_011651064010_0            51     Toulon          WV02
# WV02_Toulon_2016_03_22_011651057010_0            52     Toulon          WV02
# WV02_Toulon_2016_03_25_011651060010_0            53     Toulon          WV02
# WV02_Toulon_2016_03_30_011651053010_0            54     Toulon          WV02
# WV02_Toulon_2016_09_28_011651048010_0            55     Toulon          WV02
# WV02_Toulon_2017_08_19_011651059010_0            56     Toulon          WV02
# WV02_Toulon_2019_07_29_011650877010_0            57     Toulon          WV02
# WV02_Toulon_2019_08_04_011650878010_0            58     Toulon          WV02
# WV02_Toulon_2019_09_11_011650876010_0            59     Toulon          WV02
# WV02_Toulon_2019_10_16_011650874010_0            60     Toulon          WV02
# WV02_Toulon_2019_12_15_011650875010_0            61     Toulon          WV02
# WV03_La_Spezia_2016_01_03_011650743010_0         62  La_Spezia     WV03_VNIR
# WV03_La_Spezia_2018_08_06_011650747010_0         63  La_Spezia     WV03_VNIR
# WV03_VNIR_Toulon_2015_04_09_011650880010_0       64     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2015_07_01_011650884010_0       65     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2016_01_01_011650881010_0       66     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2016_02_08_011650888010_0       67     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2016_04_05_011650879010_0       68     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2016_04_11_011650882010_0       69     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2017_07_03_011650887010_0       70     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2018_10_03_011650886010_0       71     Toulon     WV03_VNIR
# WV03_VNIR_Toulon_2019_02_11_011650889010_0       72     Toulon     WV03_VNIR
#
#                                            pan_catalogIdentifier  \
# GE01_La_Spezia_2009_09_25_011651186010_0        2030010563489B00
# GE01_La_Spezia_2011_01_24_011651197010_0        2030010563690B00
# GE01_La_Spezia_2012_02_23_011651192010_0        2030010563727300
# GE01_La_Spezia_2012_05_07_011651189010_0        2030010563738800
# GE01_La_Spezia_2012_05_16_011651187010_0        2030010563726F00
# GE01_La_Spezia_2013_07_07_011651184010_0        2030010563735C00
# GE01_La_Spezia_2013_07_15_011651183010_0        2030010563737600
# GE01_La_Spezia_2013_07_18_011651195010_0        2030010563719700
# GE01_La_Spezia_2013_07_23_011651202010_0        20300105636D9400
# GE01_La_Spezia_2017_04_16_011651188010_0        2030010563736D00
# GE01_La_Spezia_2019_01_03_011651196010_0        203001056371F100
# GE01_Toulon 2009_03_23_011651190010_0           2030010563738900
# GE01_Toulon 2010_06_08_011651191010_0           2030010563733400
# GE01_Toulon 2013_08_20_011651198010_0           2030010563465E00
# GE01_Toulon 2014_10_16_011651185010_0           203001056372E200
# GE01_Toulon 2016_03_26_011651193010_0           2030010563482700
# GE01_Toulon 2016_09_21_011651200010_0           203001056372F600
# GE01_Toulon 2017_09_05_011651201010_0           2030010563733200
# GE01_Toulon 2018_02_13_011651199010_0           203001056371EB00
# GE01_Toulon 2019_10_07_011651194010_0           2030010563158400
# WV02_La_Spezia_2010_08_06_011650744010_0        20300105635BC200
# WV02_La_Spezia_2011_05_02_011650586010_0        2030010563517600
# WV02_La_Spezia_2011_05_10_011650587010_0        203001056350B200
# WV02_La_Spezia_2011_10_28_011650745010_0        2030010563350A00
# WV02_La_Spezia_2012_01_10_011650582010_0        2030010563525500
# WV02_La_Spezia_2012_05_17_011650585010_0        2030010563306700
# WV02_La_Spezia_2013_10_31_011650588010_0        203001056351E500
# WV02_La_Spezia_2013_12_08_011650589010_0        2030010563517300
# WV02_La_Spezia_2014_11_20_011650595010_0        2030010563525300
# WV02_La_Spezia_2015_01_05_011650746010_0        2030010563598800
# WV02_La_Spezia_2015_03_19_011650598010_0        203001056350CE00
# WV02_La_Spezia_2015_03_19_011650600010_0        203001056350EC00
# WV02_La_Spezia_2015_04_24_011650748010_0        203001056359B800
# WV02_La_Spezia_2015_05_21_011650592010_0        2030010563517D00
# WV02_La_Spezia_2017_03_10_011650750010_0        2030010563573100
# WV02_La_Spezia_2017_07_31_011650593010_0        203001056351CF00
# WV02_La_Spezia_2018_05_18_011650597010_0        2030010563526100
# WV02_La_Spezia_2018_05_29_011650583010_0        203001056351E200
# WV02_La_Spezia_2018_07_06_011650749010_0        2030010563593500
# WV02_La_Spezia_2019_05_23_011650590010_0        20300105634FCE00
# WV02_La_Spezia_2019_06_03_011650596010_0        203001056350B800
# WV02_La_Spezia_2019_10_11_011650594010_0        203001056301AE00
# WV02_Toulon_2010_11_04_011651051010_0           20300105636D8800
# WV02_Toulon_2011_05_04_011651058010_0           203001056312A600
# WV02_Toulon_2011_12_22_011651063010_0           20300105636DC500
# WV02_Toulon_2013_03_16_011651062010_0           2030010563428C00
# WV02_Toulon_2013_04_07_011651056010_0           203001056312A000
# WV02_Toulon_2013_04_10_011651050010_0           20300105636D7B00
# WV02_Toulon_2013_10_09_011651061010_0           20300105636DA100
# WV02_Toulon_2014_04_06_011651052010_0           20300105636D8200
# WV02_Toulon_2015_11_16_011651049010_0           203001056359AD00
# WV02_Toulon_2016_03_14_011651064010_0           20300105636D9800
# WV02_Toulon_2016_03_22_011651057010_0           20300105636D8500
# WV02_Toulon_2016_03_25_011651060010_0           20300105636D8F00
# WV02_Toulon_2016_03_30_011651053010_0           20300105636D9500
# WV02_Toulon_2016_09_28_011651048010_0           20300105636D2E00
# WV02_Toulon_2017_08_19_011651059010_0           20300105636D9D00
# WV02_Toulon_2019_07_29_011650877010_0           20300105630ECF00
# WV02_Toulon_2019_08_04_011650878010_0           20300105630ECC00
# WV02_Toulon_2019_09_11_011650876010_0           20300105630EBC00
# WV02_Toulon_2019_10_16_011650874010_0           20300105630EC000
# WV02_Toulon_2019_12_15_011650875010_0           20300105630EC600
# WV03_La_Spezia_2016_01_03_011650743010_0        20300105635AAB00
# WV03_La_Spezia_2018_08_06_011650747010_0        203001056358FE00
# WV03_VNIR_Toulon_2015_04_09_011650880010_0      2030010563694700
# WV03_VNIR_Toulon_2015_07_01_011650884010_0      20300105630F0300
# WV03_VNIR_Toulon_2016_01_01_011650881010_0      2030010563691500
# WV03_VNIR_Toulon_2016_02_08_011650888010_0      203001056369A400
# WV03_VNIR_Toulon_2016_04_05_011650879010_0      20300105630F0600
# WV03_VNIR_Toulon_2016_04_11_011650882010_0      20300105630F0C00
# WV03_VNIR_Toulon_2017_07_03_011650887010_0      20300105630EF400
# WV03_VNIR_Toulon_2018_10_03_011650886010_0      2030010563692900
# WV03_VNIR_Toulon_2019_02_11_011650889010_0      2030010563692500
#
#                                            ms_catalogIdentifier  \
# GE01_La_Spezia_2009_09_25_011651186010_0       2030010563489800
# GE01_La_Spezia_2011_01_24_011651197010_0       2030010563690500
# GE01_La_Spezia_2012_02_23_011651192010_0       2030010563727000
# GE01_La_Spezia_2012_05_07_011651189010_0       2030010563738300
# GE01_La_Spezia_2012_05_16_011651187010_0       2030010563726D00
# GE01_La_Spezia_2013_07_07_011651184010_0       2030010563735A00
# GE01_La_Spezia_2013_07_15_011651183010_0       2030010563737400
# GE01_La_Spezia_2013_07_18_011651195010_0       2030010563719400
# GE01_La_Spezia_2013_07_23_011651202010_0       20300105636D9200
# GE01_La_Spezia_2017_04_16_011651188010_0       2030010563736900
# GE01_La_Spezia_2019_01_03_011651196010_0       203001056371EC00
# GE01_Toulon 2009_03_23_011651190010_0          2030010563738500
# GE01_Toulon 2010_06_08_011651191010_0          2030010563733000
# GE01_Toulon 2013_08_20_011651198010_0          2030010563465800
# GE01_Toulon 2014_10_16_011651185010_0          203001056372DA00
# GE01_Toulon 2016_03_26_011651193010_0          2030010563482300
# GE01_Toulon 2016_09_21_011651200010_0          203001056372F300
# GE01_Toulon 2017_09_05_011651201010_0          2030010563732D00
# GE01_Toulon 2018_02_13_011651199010_0          203001056371E400
# GE01_Toulon 2019_10_07_011651194010_0          2030010563158200
# WV02_La_Spezia_2010_08_06_011650744010_0       20300105635BC400
# WV02_La_Spezia_2011_05_02_011650586010_0       2030010563517A00
# WV02_La_Spezia_2011_05_10_011650587010_0       203001056350B400
# WV02_La_Spezia_2011_10_28_011650745010_0       2030010563350D00
# WV02_La_Spezia_2012_01_10_011650582010_0       2030010563525B00
# WV02_La_Spezia_2012_05_17_011650585010_0       2030010563306900
# WV02_La_Spezia_2013_10_31_011650588010_0       203001056351E700
# WV02_La_Spezia_2013_12_08_011650589010_0       2030010563517800
# WV02_La_Spezia_2014_11_20_011650595010_0       2030010563525A00
# WV02_La_Spezia_2015_01_05_011650746010_0       2030010563598A00
# WV02_La_Spezia_2015_03_19_011650598010_0       203001056350D000
# WV02_La_Spezia_2015_03_19_011650600010_0       203001056350EE00
# WV02_La_Spezia_2015_04_24_011650748010_0       203001056359BB00
# WV02_La_Spezia_2015_05_21_011650592010_0       2030010563517F00
# WV02_La_Spezia_2017_03_10_011650750010_0       2030010563573400
# WV02_La_Spezia_2017_07_31_011650593010_0       203001056351D100
# WV02_La_Spezia_2018_05_18_011650597010_0       2030010563526300
# WV02_La_Spezia_2018_05_29_011650583010_0       203001056351E400
# WV02_La_Spezia_2018_07_06_011650749010_0       2030010563593700
# WV02_La_Spezia_2019_05_23_011650590010_0       20300105634FD000
# WV02_La_Spezia_2019_06_03_011650596010_0       203001056350BA00
# WV02_La_Spezia_2019_10_11_011650594010_0       203001056301B100
# WV02_Toulon_2010_11_04_011651051010_0          20300105636D8A00
# WV02_Toulon_2011_05_04_011651058010_0          203001056312A800
# WV02_Toulon_2011_12_22_011651063010_0          20300105636DC800
# WV02_Toulon_2013_03_16_011651062010_0          2030010563429000
# WV02_Toulon_2013_04_07_011651056010_0          203001056312A200
# WV02_Toulon_2013_04_10_011651050010_0          20300105636D7F00
# WV02_Toulon_2013_10_09_011651061010_0          20300105636DA300
# WV02_Toulon_2014_04_06_011651052010_0          20300105636D8400
# WV02_Toulon_2015_11_16_011651049010_0          203001056359AF00
# WV02_Toulon_2016_03_14_011651064010_0          20300105636D9A00
# WV02_Toulon_2016_03_22_011651057010_0          20300105636D8700
# WV02_Toulon_2016_03_25_011651060010_0          20300105636D9100
# WV02_Toulon_2016_03_30_011651053010_0          20300105636D9700
# WV02_Toulon_2016_09_28_011651048010_0          20300105636D3000
# WV02_Toulon_2017_08_19_011651059010_0          20300105636D9F00
# WV02_Toulon_2019_07_29_011650877010_0          20300105630ED300
# WV02_Toulon_2019_08_04_011650878010_0          20300105630ECE00
# WV02_Toulon_2019_09_11_011650876010_0          20300105630EBF00
# WV02_Toulon_2019_10_16_011650874010_0          20300105630EC200
# WV02_Toulon_2019_12_15_011650875010_0          20300105630EC800
# WV03_La_Spezia_2016_01_03_011650743010_0       20300105635AB000
# WV03_La_Spezia_2018_08_06_011650747010_0       2030010563590500
# WV03_VNIR_Toulon_2015_04_09_011650880010_0     2030010563694B00
# WV03_VNIR_Toulon_2015_07_01_011650884010_0     20300105630F0500
# WV03_VNIR_Toulon_2016_01_01_011650881010_0     2030010563691700
# WV03_VNIR_Toulon_2016_02_08_011650888010_0     203001056369A600
# WV03_VNIR_Toulon_2016_04_05_011650879010_0     20300105630F0800
# WV03_VNIR_Toulon_2016_04_11_011650882010_0     20300105630F0E00
# WV03_VNIR_Toulon_2017_07_03_011650887010_0     20300105630EF600
# WV03_VNIR_Toulon_2018_10_03_011650886010_0     2030010563692C00
# WV03_VNIR_Toulon_2019_02_11_011650889010_0     2030010563692700
#
#                                            pan_processedProductId  \
# GE01_La_Spezia_2009_09_25_011651186010_0                 64917094
# GE01_La_Spezia_2011_01_24_011651197010_0                 64922844
# GE01_La_Spezia_2012_02_23_011651192010_0                 64924632
# GE01_La_Spezia_2012_05_07_011651189010_0                 64924875
# GE01_La_Spezia_2012_05_16_011651187010_0                 64924628
# GE01_La_Spezia_2013_07_07_011651184010_0                 64924836
# GE01_La_Spezia_2013_07_15_011651183010_0                 64924861
# GE01_La_Spezia_2013_07_18_011651195010_0                 64924443
# GE01_La_Spezia_2013_07_23_011651202010_0                 64923685
# GE01_La_Spezia_2017_04_16_011651188010_0                 64924855
# GE01_La_Spezia_2019_01_03_011651196010_0                 64924521
# GE01_Toulon 2009_03_23_011651190010_0                    64924879
# GE01_Toulon 2010_06_08_011651191010_0                    64924794
# GE01_Toulon 2013_08_20_011651198010_0                    64916679
# GE01_Toulon 2014_10_16_011651185010_0                    64924722
# GE01_Toulon 2016_03_26_011651193010_0                    64917002
# GE01_Toulon 2016_09_21_011651200010_0                    64924734
# GE01_Toulon 2017_09_05_011651201010_0                    64924791
# GE01_Toulon 2018_02_13_011651199010_0                    64924517
# GE01_Toulon 2019_10_07_011651194010_0                    64907880
# WV02_La_Spezia_2010_08_06_011650744010_0                 64920520
# WV02_La_Spezia_2011_05_02_011650586010_0                 64918728
# WV02_La_Spezia_2011_05_10_011650587010_0                 64918572
# WV02_La_Spezia_2011_10_28_011650745010_0                 64913587
# WV02_La_Spezia_2012_01_10_011650582010_0                 64918882
# WV02_La_Spezia_2012_05_17_011650585010_0                 64912750
# WV02_La_Spezia_2013_10_31_011650588010_0                 64918799
# WV02_La_Spezia_2013_12_08_011650589010_0                 64918731
# WV02_La_Spezia_2014_11_20_011650595010_0                 64918880
# WV02_La_Spezia_2015_01_05_011650746010_0                 64920135
# WV02_La_Spezia_2015_03_19_011650598010_0                 64918598
# WV02_La_Spezia_2015_03_19_011650600010_0                 64918625
# WV02_La_Spezia_2015_04_24_011650748010_0                 64920188
# WV02_La_Spezia_2015_05_21_011650592010_0                 64918736
# WV02_La_Spezia_2017_03_10_011650750010_0                 64919742
# WV02_La_Spezia_2017_07_31_011650593010_0                 64918791
# WV02_La_Spezia_2018_05_18_011650597010_0                 64918887
# WV02_La_Spezia_2018_05_29_011650583010_0                 64918801
# WV02_La_Spezia_2018_07_06_011650749010_0                 64920097
# WV02_La_Spezia_2019_05_23_011650590010_0                 64918376
# WV02_La_Spezia_2019_06_03_011650596010_0                 64918579
# WV02_La_Spezia_2019_10_11_011650594010_0                 64904435
# WV02_Toulon_2010_11_04_011651051010_0                    64923680
# WV02_Toulon_2011_05_04_011651058010_0                    64907387
# WV02_Toulon_2011_12_22_011651063010_0                    64923731
# WV02_Toulon_2013_03_16_011651062010_0                    64915989
# WV02_Toulon_2013_04_07_011651056010_0                    64907383
# WV02_Toulon_2013_04_10_011651050010_0                    64923667
# WV02_Toulon_2013_10_09_011651061010_0                    64923696
# WV02_Toulon_2014_04_06_011651052010_0                    64923671
# WV02_Toulon_2015_11_16_011651049010_0                    64920167
# WV02_Toulon_2016_03_14_011651064010_0                    64923689
# WV02_Toulon_2016_03_22_011651057010_0                    64923677
# WV02_Toulon_2016_03_25_011651060010_0                    64923683
# WV02_Toulon_2016_03_30_011651053010_0                    64923687
# WV02_Toulon_2016_09_28_011651048010_0                    64923613
# WV02_Toulon_2017_08_19_011651059010_0                    64923692
# WV02_Toulon_2019_07_29_011650877010_0                    64906697
# WV02_Toulon_2019_08_04_011650878010_0                    64906695
# WV02_Toulon_2019_09_11_011650876010_0                    64906685
# WV02_Toulon_2019_10_16_011650874010_0                    64906689
# WV02_Toulon_2019_12_15_011650875010_0                    64906691
# WV03_La_Spezia_2016_01_03_011650743010_0                 64920343
# WV03_La_Spezia_2018_08_06_011650747010_0                 64920059
# WV03_VNIR_Toulon_2015_04_09_011650880010_0               64922885
# WV03_VNIR_Toulon_2015_07_01_011650884010_0               64906735
# WV03_VNIR_Toulon_2016_01_01_011650881010_0               64922864
# WV03_VNIR_Toulon_2016_02_08_011650888010_0               64922967
# WV03_VNIR_Toulon_2016_04_05_011650879010_0               64906737
# WV03_VNIR_Toulon_2016_04_11_011650882010_0               64906739
# WV03_VNIR_Toulon_2017_07_03_011650887010_0               64906724
# WV03_VNIR_Toulon_2018_10_03_011650886010_0               64922873
# WV03_VNIR_Toulon_2019_02_11_011650889010_0               64922869
#
#                                            ms_processedProductId orderNumber  \
# GE01_La_Spezia_2009_09_25_011651186010_0                64917095   011651186
# GE01_La_Spezia_2011_01_24_011651197010_0                64922845   011651197
# GE01_La_Spezia_2012_02_23_011651192010_0                64924633   011651192
# GE01_La_Spezia_2012_05_07_011651189010_0                64924876   011651189
# GE01_La_Spezia_2012_05_16_011651187010_0                64924629   011651187
# GE01_La_Spezia_2013_07_07_011651184010_0                64924837   011651184
# GE01_La_Spezia_2013_07_15_011651183010_0                64924862   011651183
# GE01_La_Spezia_2013_07_18_011651195010_0                64924444   011651195
# GE01_La_Spezia_2013_07_23_011651202010_0                64923686   011651202
# GE01_La_Spezia_2017_04_16_011651188010_0                64924856   011651188
# GE01_La_Spezia_2019_01_03_011651196010_0                64924523   011651196
# GE01_Toulon 2009_03_23_011651190010_0                   64924880   011651190
# GE01_Toulon 2010_06_08_011651191010_0                   64924795   011651191
# GE01_Toulon 2013_08_20_011651198010_0                   64916681   011651198
# GE01_Toulon 2014_10_16_011651185010_0                   64924723   011651185
# GE01_Toulon 2016_03_26_011651193010_0                   64917003   011651193
# GE01_Toulon 2016_09_21_011651200010_0                   64924735   011651200
# GE01_Toulon 2017_09_05_011651201010_0                   64924792   011651201
# GE01_Toulon 2018_02_13_011651199010_0                   64924518   011651199
# GE01_Toulon 2019_10_07_011651194010_0                   64907881   011651194
# WV02_La_Spezia_2010_08_06_011650744010_0                64920522   011650744
# WV02_La_Spezia_2011_05_02_011650586010_0                64918729   011650586
# WV02_La_Spezia_2011_05_10_011650587010_0                64918573   011650587
# WV02_La_Spezia_2011_10_28_011650745010_0                64913588   011650745
# WV02_La_Spezia_2012_01_10_011650582010_0                64918883   011650582
# WV02_La_Spezia_2012_05_17_011650585010_0                64912751   011650585
# WV02_La_Spezia_2013_10_31_011650588010_0                64918800   011650588
# WV02_La_Spezia_2013_12_08_011650589010_0                64918732   011650589
# WV02_La_Spezia_2014_11_20_011650595010_0                64918881   011650595
# WV02_La_Spezia_2015_01_05_011650746010_0                64920137   011650746
# WV02_La_Spezia_2015_03_19_011650598010_0                64918599   011650598
# WV02_La_Spezia_2015_03_19_011650600010_0                64918626   011650600
# WV02_La_Spezia_2015_04_24_011650748010_0                64920189   011650748
# WV02_La_Spezia_2015_05_21_011650592010_0                64918737   011650592
# WV02_La_Spezia_2017_03_10_011650750010_0                64919743   011650750
# WV02_La_Spezia_2017_07_31_011650593010_0                64918792   011650593
# WV02_La_Spezia_2018_05_18_011650597010_0                64918888   011650597
# WV02_La_Spezia_2018_05_29_011650583010_0                64918802   011650583
# WV02_La_Spezia_2018_07_06_011650749010_0                64920099   011650749
# WV02_La_Spezia_2019_05_23_011650590010_0                64918377   011650590
# WV02_La_Spezia_2019_06_03_011650596010_0                64918580   011650596
# WV02_La_Spezia_2019_10_11_011650594010_0                64904436   011650594
# WV02_Toulon_2010_11_04_011651051010_0                   64923681   011651051
# WV02_Toulon_2011_05_04_011651058010_0                   64907388   011651058
# WV02_Toulon_2011_12_22_011651063010_0                   64923732   011651063
# WV02_Toulon_2013_03_16_011651062010_0                   64915990   011651062
# WV02_Toulon_2013_04_07_011651056010_0                   64907384   011651056
# WV02_Toulon_2013_04_10_011651050010_0                   64923668   011651050
# WV02_Toulon_2013_10_09_011651061010_0                   64923697   011651061
# WV02_Toulon_2014_04_06_011651052010_0                   64923672   011651052
# WV02_Toulon_2015_11_16_011651049010_0                   64920169   011651049
# WV02_Toulon_2016_03_14_011651064010_0                   64923690   011651064
# WV02_Toulon_2016_03_22_011651057010_0                   64923678   011651057
# WV02_Toulon_2016_03_25_011651060010_0                   64923684   011651060
# WV02_Toulon_2016_03_30_011651053010_0                   64923688   011651053
# WV02_Toulon_2016_09_28_011651048010_0                   64923614   011651048
# WV02_Toulon_2017_08_19_011651059010_0                   64923693   011651059
# WV02_Toulon_2019_07_29_011650877010_0                   64906698   011650877
# WV02_Toulon_2019_08_04_011650878010_0                   64906696   011650878
# WV02_Toulon_2019_09_11_011650876010_0                   64906686   011650876
# WV02_Toulon_2019_10_16_011650874010_0                   64906690   011650874
# WV02_Toulon_2019_12_15_011650875010_0                   64906692   011650875
# WV03_La_Spezia_2016_01_03_011650743010_0                64920344   011650743
# WV03_La_Spezia_2018_08_06_011650747010_0                64920060   011650747
# WV03_VNIR_Toulon_2015_04_09_011650880010_0              64922886   011650880
# WV03_VNIR_Toulon_2015_07_01_011650884010_0              64906736   011650884
# WV03_VNIR_Toulon_2016_01_01_011650881010_0              64922865   011650881
# WV03_VNIR_Toulon_2016_02_08_011650888010_0              64922968   011650888
# WV03_VNIR_Toulon_2016_04_05_011650879010_0              64906738   011650879
# WV03_VNIR_Toulon_2016_04_11_011650882010_0              64906740   011650882
# WV03_VNIR_Toulon_2017_07_03_011650887010_0              64906725   011650887
# WV03_VNIR_Toulon_2018_10_03_011650886010_0              64922874   011650886
# WV03_VNIR_Toulon_2019_02_11_011650889010_0              64922870   011650889
#
#                                                             acquisitionTime  \
# GE01_La_Spezia_2009_09_25_011651186010_0   2009-09-25 10:20:15.452590+00:00
# GE01_La_Spezia_2011_01_24_011651197010_0   2011-01-24 10:22:46.106348+00:00
# GE01_La_Spezia_2012_02_23_011651192010_0   2012-02-23 10:13:21.177971+00:00
# GE01_La_Spezia_2012_05_07_011651189010_0   2012-05-07 10:08:51.451091+00:00
# GE01_La_Spezia_2012_05_16_011651187010_0   2012-05-16 10:35:28.662715+00:00
# GE01_La_Spezia_2013_07_07_011651184010_0   2013-07-07 10:27:39.584734+00:00
# GE01_La_Spezia_2013_07_15_011651183010_0   2013-07-15 10:19:13.153157+00:00
# GE01_La_Spezia_2013_07_18_011651195010_0   2013-07-18 10:28:18.195235+00:00
# GE01_La_Spezia_2013_07_23_011651202010_0   2013-07-23 10:10:19.755750+00:00
# GE01_La_Spezia_2017_04_16_011651188010_0   2017-04-16 10:32:44.196268+00:00
# GE01_La_Spezia_2019_01_03_011651196010_0   2019-01-03 10:13:18.715291+00:00
# GE01_Toulon 2009_03_23_011651190010_0      2009-03-23 10:42:16.141612+00:00
# GE01_Toulon 2010_06_08_011651191010_0      2010-06-08 10:44:18.463641+00:00
# GE01_Toulon 2013_08_20_011651198010_0      2013-08-20 10:31:47.753515+00:00
# GE01_Toulon 2014_10_16_011651185010_0      2014-10-16 10:28:18.197488+00:00
# GE01_Toulon 2016_03_26_011651193010_0      2016-03-26 10:47:43.844554+00:00
# GE01_Toulon 2016_09_21_011651200010_0      2016-09-21 10:23:00.673210+00:00
# GE01_Toulon 2017_09_05_011651201010_0      2017-09-05 10:45:41.112507+00:00
# GE01_Toulon 2018_02_13_011651199010_0      2018-02-13 10:46:04.416071+00:00
# GE01_Toulon 2019_10_07_011651194010_0      2019-10-07 10:25:37.657122+00:00
# WV02_La_Spezia_2010_08_06_011650744010_0   2010-08-06 10:21:56.187460+00:00
# WV02_La_Spezia_2011_05_02_011650586010_0   2011-05-02 10:34:35.974780+00:00
# WV02_La_Spezia_2011_05_10_011650587010_0   2011-05-10 10:41:18.468932+00:00
# WV02_La_Spezia_2011_10_28_011650745010_0   2011-10-28 11:15:45.928566+00:00
# WV02_La_Spezia_2012_01_10_011650582010_0   2012-01-10 10:55:40.321329+00:00
# WV02_La_Spezia_2012_05_17_011650585010_0   2012-05-17 10:43:08.869809+00:00
# WV02_La_Spezia_2013_10_31_011650588010_0   2013-10-31 10:40:04.697446+00:00
# WV02_La_Spezia_2013_12_08_011650589010_0   2013-12-08 10:41:49.521940+00:00
# WV02_La_Spezia_2014_11_20_011650595010_0   2014-11-20 10:45:48.034921+00:00
# WV02_La_Spezia_2015_01_05_011650746010_0   2015-01-05 10:46:56.440104+00:00
# WV02_La_Spezia_2015_03_19_011650598010_0   2015-03-19 10:50:06.911027+00:00
# WV02_La_Spezia_2015_03_19_011650600010_0   2015-03-19 10:50:06.911027+00:00
# WV02_La_Spezia_2015_04_24_011650748010_0   2015-04-24 10:20:27.007753+00:00
# WV02_La_Spezia_2015_05_21_011650592010_0   2015-05-21 10:23:10.593428+00:00
# WV02_La_Spezia_2017_03_10_011650750010_0   2017-03-10 10:14:18.936541+00:00
# WV02_La_Spezia_2017_07_31_011650593010_0   2017-07-31 10:36:08.345224+00:00
# WV02_La_Spezia_2018_05_18_011650597010_0   2018-05-18 10:35:44.427670+00:00
# WV02_La_Spezia_2018_05_29_011650583010_0   2018-05-29 10:31:32.579803+00:00
# WV02_La_Spezia_2018_07_06_011650749010_0   2018-07-06 10:34:42.078546+00:00
# WV02_La_Spezia_2019_05_23_011650590010_0   2019-05-23 10:30:38.722957+00:00
# WV02_La_Spezia_2019_06_03_011650596010_0   2019-06-03 10:25:47.678602+00:00
# WV02_La_Spezia_2019_10_11_011650594010_0   2019-10-11 10:37:48.621914+00:00
# WV02_Toulon_2010_11_04_011651051010_0      2010-11-04 10:53:11.759011+00:00
# WV02_Toulon_2011_05_04_011651058010_0      2011-05-04 11:01:46.806361+00:00
# WV02_Toulon_2011_12_22_011651063010_0      2011-12-22 10:55:02.006924+00:00
# WV02_Toulon_2013_03_16_011651062010_0      2013-03-16 11:14:07.677887+00:00
# WV02_Toulon_2013_04_07_011651056010_0      2013-04-07 11:04:09.492946+00:00
# WV02_Toulon_2013_04_10_011651050010_0      2013-04-10 10:54:15.912680+00:00
# WV02_Toulon_2013_10_09_011651061010_0      2013-10-09 10:50:24.203698+00:00
# WV02_Toulon_2014_04_06_011651052010_0      2014-04-06 10:57:37.006411+00:00
# WV02_Toulon_2015_11_16_011651049010_0      2015-11-16 10:25:07.310560+00:00
# WV02_Toulon_2016_03_14_011651064010_0      2016-03-14 10:37:10.324076+00:00
# WV02_Toulon_2016_03_22_011651057010_0      2016-03-22 10:41:52.677995+00:00
# WV02_Toulon_2016_03_25_011651060010_0      2016-03-25 10:31:03.639724+00:00
# WV02_Toulon_2016_03_30_011651053010_0      2016-03-30 10:46:09.382841+00:00
# WV02_Toulon_2016_09_28_011651048010_0      2016-09-28 10:32:19.577472+00:00
# WV02_Toulon_2017_08_19_011651059010_0      2017-08-19 10:37:23.226188+00:00
# WV02_Toulon_2019_07_29_011650877010_0      2019-07-29 11:02:20.771031+00:00
# WV02_Toulon_2019_08_04_011650878010_0      2019-08-04 10:42:25.257462+00:00
# WV02_Toulon_2019_09_11_011650876010_0      2019-09-11 10:42:29.603580+00:00
# WV02_Toulon_2019_10_16_011650874010_0      2019-10-16 10:53:51.547908+00:00
# WV02_Toulon_2019_12_15_011650875010_0      2019-12-15 10:42:58.451954+00:00
# WV03_La_Spezia_2016_01_03_011650743010_0   2016-01-13 10:40:36.234257+00:00
# WV03_La_Spezia_2018_08_06_011650747010_0   2018-08-06 10:36:29.441492+00:00
# WV03_VNIR_Toulon_2015_04_09_011650880010_0 2015-04-09 10:23:35.429408+00:00
# WV03_VNIR_Toulon_2015_07_01_011650884010_0 2015-07-01 10:33:52.112278+00:00
# WV03_VNIR_Toulon_2016_01_01_011650881010_0 2016-01-01 10:51:25.263449+00:00
# WV03_VNIR_Toulon_2016_02_08_011650888010_0 2016-02-08 10:49:23.919610+00:00
# WV03_VNIR_Toulon_2016_04_05_011650879010_0 2016-04-05 10:51:20.430697+00:00
# WV03_VNIR_Toulon_2016_04_11_011650882010_0 2016-04-11 10:46:38.954045+00:00
# WV03_VNIR_Toulon_2017_07_03_011650887010_0 2017-07-03 10:57:04.074633+00:00
# WV03_VNIR_Toulon_2018_10_03_011650886010_0 2018-10-03 11:00:04.557207+00:00
# WV03_VNIR_Toulon_2019_02_11_011650889010_0 2019-02-11 10:47:36.251949+00:00
#
#                                                       productionDate  \
# GE01_La_Spezia_2009_09_25_011651186010_0   2019-12-18 18:11:09+00:00
# GE01_La_Spezia_2011_01_24_011651197010_0   2019-12-18 20:14:09+00:00
# GE01_La_Spezia_2012_02_23_011651192010_0   2019-12-18 21:26:36+00:00
# GE01_La_Spezia_2012_05_07_011651189010_0   2019-12-18 21:33:02+00:00
# GE01_La_Spezia_2012_05_16_011651187010_0   2019-12-18 21:26:25+00:00
# GE01_La_Spezia_2013_07_07_011651184010_0   2019-12-18 21:31:11+00:00
# GE01_La_Spezia_2013_07_15_011651183010_0   2019-12-18 21:32:21+00:00
# GE01_La_Spezia_2013_07_18_011651195010_0   2019-12-18 21:22:16+00:00
# GE01_La_Spezia_2013_07_23_011651202010_0   2019-12-18 20:57:39+00:00
# GE01_La_Spezia_2017_04_16_011651188010_0   2019-12-18 21:31:38+00:00
# GE01_La_Spezia_2019_01_03_011651196010_0   2019-12-18 21:23:21+00:00
# GE01_Toulon 2009_03_23_011651190010_0      2019-12-18 21:33:04+00:00
# GE01_Toulon 2010_06_08_011651191010_0      2019-12-18 21:30:05+00:00
# GE01_Toulon 2013_08_20_011651198010_0      2019-12-18 17:59:08+00:00
# GE01_Toulon 2014_10_16_011651185010_0      2019-12-18 21:28:03+00:00
# GE01_Toulon 2016_03_26_011651193010_0      2019-12-18 18:08:49+00:00
# GE01_Toulon 2016_09_21_011651200010_0      2019-12-18 21:28:26+00:00
# GE01_Toulon 2017_09_05_011651201010_0      2019-12-18 21:30:06+00:00
# GE01_Toulon 2018_02_13_011651199010_0      2019-12-18 21:23:30+00:00
# GE01_Toulon 2019_10_07_011651194010_0      2019-12-18 12:44:09+00:00
# WV02_La_Spezia_2010_08_06_011650744010_0   2019-12-18 19:38:04+00:00
# WV02_La_Spezia_2011_05_02_011650586010_0   2019-12-18 19:01:11+00:00
# WV02_La_Spezia_2011_05_10_011650587010_0   2019-12-18 18:55:17+00:00
# WV02_La_Spezia_2011_10_28_011650745010_0   2019-12-18 16:00:44+00:00
# WV02_La_Spezia_2012_01_10_011650582010_0   2019-12-18 19:05:31+00:00
# WV02_La_Spezia_2012_05_17_011650585010_0   2019-12-18 15:42:33+00:00
# WV02_La_Spezia_2013_10_31_011650588010_0   2019-12-18 19:03:17+00:00
# WV02_La_Spezia_2013_12_08_011650589010_0   2019-12-18 19:01:08+00:00
# WV02_La_Spezia_2014_11_20_011650595010_0   2019-12-18 19:05:32+00:00
# WV02_La_Spezia_2015_01_05_011650746010_0   2019-12-18 19:33:39+00:00
# WV02_La_Spezia_2015_03_19_011650598010_0   2019-12-18 18:55:37+00:00
# WV02_La_Spezia_2015_03_19_011650600010_0   2019-12-18 18:56:50+00:00
# WV02_La_Spezia_2015_04_24_011650748010_0   2019-12-18 19:33:59+00:00
# WV02_La_Spezia_2015_05_21_011650592010_0   2019-12-18 19:01:16+00:00
# WV02_La_Spezia_2017_03_10_011650750010_0   2019-12-18 19:28:07+00:00
# WV02_La_Spezia_2017_07_31_011650593010_0   2019-12-18 19:03:01+00:00
# WV02_La_Spezia_2018_05_18_011650597010_0   2019-12-18 19:05:47+00:00
# WV02_La_Spezia_2018_05_29_011650583010_0   2019-12-18 19:03:17+00:00
# WV02_La_Spezia_2018_07_06_011650749010_0   2019-12-18 19:32:57+00:00
# WV02_La_Spezia_2019_05_23_011650590010_0   2019-12-18 18:46:06+00:00
# WV02_La_Spezia_2019_06_03_011650596010_0   2019-12-18 18:55:17+00:00
# WV02_La_Spezia_2019_10_11_011650594010_0   2019-12-18 10:22:21+00:00
# WV02_Toulon_2010_11_04_011651051010_0      2019-12-18 20:55:57+00:00
# WV02_Toulon_2011_05_04_011651058010_0      2019-12-18 12:07:33+00:00
# WV02_Toulon_2011_12_22_011651063010_0      2019-12-18 21:04:01+00:00
# WV02_Toulon_2013_03_16_011651062010_0      2019-12-18 17:34:25+00:00
# WV02_Toulon_2013_04_07_011651056010_0      2019-12-18 12:06:35+00:00
# WV02_Toulon_2013_04_10_011651050010_0      2019-12-18 20:55:27+00:00
# WV02_Toulon_2013_10_09_011651061010_0      2019-12-18 20:58:13+00:00
# WV02_Toulon_2014_04_06_011651052010_0      2019-12-18 20:55:52+00:00
# WV02_Toulon_2015_11_16_011651049010_0      2019-12-18 19:33:57+00:00
# WV02_Toulon_2016_03_14_011651064010_0      2019-12-18 20:57:43+00:00
# WV02_Toulon_2016_03_22_011651057010_0      2019-12-18 20:56:17+00:00
# WV02_Toulon_2016_03_25_011651060010_0      2019-12-18 20:57:23+00:00
# WV02_Toulon_2016_03_30_011651053010_0      2019-12-18 20:57:42+00:00
# WV02_Toulon_2016_09_28_011651048010_0      2019-12-18 20:51:39+00:00
# WV02_Toulon_2017_08_19_011651059010_0      2019-12-18 20:58:09+00:00
# WV02_Toulon_2019_07_29_011650877010_0      2019-12-18 11:25:47+00:00
# WV02_Toulon_2019_08_04_011650878010_0      2019-12-18 11:25:43+00:00
# WV02_Toulon_2019_09_11_011650876010_0      2019-12-18 11:25:15+00:00
# WV02_Toulon_2019_10_16_011650874010_0      2019-12-18 11:25:31+00:00
# WV02_Toulon_2019_12_15_011650875010_0      2019-12-18 11:25:44+00:00
# WV03_La_Spezia_2016_01_03_011650743010_0   2019-12-18 19:36:00+00:00
# WV03_La_Spezia_2018_08_06_011650747010_0   2019-12-18 19:32:22+00:00
# WV03_VNIR_Toulon_2015_04_09_011650880010_0 2019-12-18 20:14:58+00:00
# WV03_VNIR_Toulon_2015_07_01_011650884010_0 2019-12-18 11:26:51+00:00
# WV03_VNIR_Toulon_2016_01_01_011650881010_0 2019-12-18 20:14:28+00:00
# WV03_VNIR_Toulon_2016_02_08_011650888010_0 2019-12-18 20:17:30+00:00
# WV03_VNIR_Toulon_2016_04_05_011650879010_0 2019-12-18 11:26:52+00:00
# WV03_VNIR_Toulon_2016_04_11_011650882010_0 2019-12-18 11:26:55+00:00
# WV03_VNIR_Toulon_2017_07_03_011650887010_0 2019-12-18 11:26:48+00:00
# WV03_VNIR_Toulon_2018_10_03_011650886010_0 2019-12-18 20:14:43+00:00
# WV03_VNIR_Toulon_2019_02_11_011650889010_0 2019-12-18 20:14:37+00:00
#
#                                                           updateDate  \
# GE01_La_Spezia_2009_09_25_011651186010_0   2019-12-18 19:03:38+00:00
# GE01_La_Spezia_2011_01_24_011651197010_0   2019-12-18 20:20:02+00:00
# GE01_La_Spezia_2012_02_23_011651192010_0   2019-12-18 22:07:12+00:00
# GE01_La_Spezia_2012_05_07_011651189010_0   2019-12-19 13:28:29+00:00
# GE01_La_Spezia_2012_05_16_011651187010_0   2019-12-19 13:17:12+00:00
# GE01_La_Spezia_2013_07_07_011651184010_0   2019-12-19 13:19:01+00:00
# GE01_La_Spezia_2013_07_15_011651183010_0   2019-12-19 13:24:04+00:00
# GE01_La_Spezia_2013_07_18_011651195010_0   2019-12-18 22:07:14+00:00
# GE01_La_Spezia_2013_07_23_011651202010_0   2019-12-18 21:02:56+00:00
# GE01_La_Spezia_2017_04_16_011651188010_0   2019-12-18 21:32:55+00:00
# GE01_La_Spezia_2019_01_03_011651196010_0   2019-12-18 21:24:27+00:00
# GE01_Toulon 2009_03_23_011651190010_0      2019-12-19 13:26:15+00:00
# GE01_Toulon 2010_06_08_011651191010_0      2019-12-19 13:21:43+00:00
# GE01_Toulon 2013_08_20_011651198010_0      2019-12-18 19:05:47+00:00
# GE01_Toulon 2014_10_16_011651185010_0      2019-12-18 21:29:13+00:00
# GE01_Toulon 2016_03_26_011651193010_0      2019-12-18 18:09:43+00:00
# GE01_Toulon 2016_09_21_011651200010_0      2019-12-18 21:29:43+00:00
# GE01_Toulon 2017_09_05_011651201010_0      2019-12-18 21:31:02+00:00
# GE01_Toulon 2018_02_13_011651199010_0      2019-12-18 21:24:19+00:00
# GE01_Toulon 2019_10_07_011651194010_0      2019-12-18 12:45:23+00:00
# WV02_La_Spezia_2010_08_06_011650744010_0   2019-12-18 19:39:05+00:00
# WV02_La_Spezia_2011_05_02_011650586010_0   2019-12-18 19:02:04+00:00
# WV02_La_Spezia_2011_05_10_011650587010_0   2019-12-18 18:55:55+00:00
# WV02_La_Spezia_2011_10_28_011650745010_0   2019-12-18 16:01:50+00:00
# WV02_La_Spezia_2012_01_10_011650582010_0   2019-12-18 19:06:14+00:00
# WV02_La_Spezia_2012_05_17_011650585010_0   2019-12-18 15:43:24+00:00
# WV02_La_Spezia_2013_10_31_011650588010_0   2019-12-18 19:04:16+00:00
# WV02_La_Spezia_2013_12_08_011650589010_0   2019-12-18 19:02:04+00:00
# WV02_La_Spezia_2014_11_20_011650595010_0   2019-12-18 19:06:13+00:00
# WV02_La_Spezia_2015_01_05_011650746010_0   2019-12-18 19:34:29+00:00
# WV02_La_Spezia_2015_03_19_011650598010_0   2019-12-18 18:56:31+00:00
# WV02_La_Spezia_2015_03_19_011650600010_0   2019-12-18 18:58:11+00:00
# WV02_La_Spezia_2015_04_24_011650748010_0   2019-12-18 19:35:05+00:00
# WV02_La_Spezia_2015_05_21_011650592010_0   2019-12-18 19:02:12+00:00
# WV02_La_Spezia_2017_03_10_011650750010_0   2019-12-18 19:29:12+00:00
# WV02_La_Spezia_2017_07_31_011650593010_0   2019-12-18 19:03:54+00:00
# WV02_La_Spezia_2018_05_18_011650597010_0   2019-12-18 19:06:27+00:00
# WV02_La_Spezia_2018_05_29_011650583010_0   2019-12-18 19:04:14+00:00
# WV02_La_Spezia_2018_07_06_011650749010_0   2019-12-18 19:33:38+00:00
# WV02_La_Spezia_2019_05_23_011650590010_0   2019-12-18 18:46:54+00:00
# WV02_La_Spezia_2019_06_03_011650596010_0   2019-12-18 18:56:24+00:00
# WV02_La_Spezia_2019_10_11_011650594010_0   2019-12-18 10:23:11+00:00
# WV02_Toulon_2010_11_04_011651051010_0      2019-12-18 20:57:20+00:00
# WV02_Toulon_2011_05_04_011651058010_0      2019-12-18 12:08:33+00:00
# WV02_Toulon_2011_12_22_011651063010_0      2019-12-18 21:04:46+00:00
# WV02_Toulon_2013_03_16_011651062010_0      2019-12-18 17:35:30+00:00
# WV02_Toulon_2013_04_07_011651056010_0      2019-12-18 12:08:02+00:00
# WV02_Toulon_2013_04_10_011651050010_0      2019-12-18 20:56:18+00:00
# WV02_Toulon_2013_10_09_011651061010_0      2019-12-18 20:59:33+00:00
# WV02_Toulon_2014_04_06_011651052010_0      2019-12-18 20:56:54+00:00
# WV02_Toulon_2015_11_16_011651049010_0      2019-12-18 19:34:51+00:00
# WV02_Toulon_2016_03_14_011651064010_0      2019-12-18 20:58:44+00:00
# WV02_Toulon_2016_03_22_011651057010_0      2019-12-18 20:56:54+00:00
# WV02_Toulon_2016_03_25_011651060010_0      2019-12-18 20:58:27+00:00
# WV02_Toulon_2016_03_30_011651053010_0      2019-12-18 20:58:35+00:00
# WV02_Toulon_2016_09_28_011651048010_0      2019-12-18 20:53:03+00:00
# WV02_Toulon_2017_08_19_011651059010_0      2019-12-18 20:59:06+00:00
# WV02_Toulon_2019_07_29_011650877010_0      2019-12-18 11:26:43+00:00
# WV02_Toulon_2019_08_04_011650878010_0      2019-12-18 11:26:42+00:00
# WV02_Toulon_2019_09_11_011650876010_0      2019-12-18 11:26:08+00:00
# WV02_Toulon_2019_10_16_011650874010_0      2019-12-18 11:26:33+00:00
# WV02_Toulon_2019_12_15_011650875010_0      2019-12-18 11:26:39+00:00
# WV03_La_Spezia_2016_01_03_011650743010_0   2019-12-18 19:37:00+00:00
# WV03_La_Spezia_2018_08_06_011650747010_0   2019-12-18 19:33:21+00:00
# WV03_VNIR_Toulon_2015_04_09_011650880010_0 2019-12-18 20:15:58+00:00
# WV03_VNIR_Toulon_2015_07_01_011650884010_0 2019-12-18 11:28:15+00:00
# WV03_VNIR_Toulon_2016_01_01_011650881010_0 2019-12-18 20:15:28+00:00
# WV03_VNIR_Toulon_2016_02_08_011650888010_0 2019-12-18 20:18:22+00:00
# WV03_VNIR_Toulon_2016_04_05_011650879010_0 2019-12-18 11:28:20+00:00
# WV03_VNIR_Toulon_2016_04_11_011650882010_0 2019-12-18 11:28:38+00:00
# WV03_VNIR_Toulon_2017_07_03_011650887010_0 2019-12-18 11:27:33+00:00
# WV03_VNIR_Toulon_2018_10_03_011650886010_0 2019-12-18 20:15:42+00:00
# WV03_VNIR_Toulon_2019_02_11_011650889010_0 2019-12-18 20:15:40+00:00
#
#                                            bitsPerPixel imageFileFormat  \
# GE01_La_Spezia_2009_09_25_011651186010_0             16         GeoTiff
# GE01_La_Spezia_2011_01_24_011651197010_0             16         GeoTiff
# GE01_La_Spezia_2012_02_23_011651192010_0             16         GeoTiff
# GE01_La_Spezia_2012_05_07_011651189010_0             16         GeoTiff
# GE01_La_Spezia_2012_05_16_011651187010_0             16         GeoTiff
# GE01_La_Spezia_2013_07_07_011651184010_0             16         GeoTiff
# GE01_La_Spezia_2013_07_15_011651183010_0             16         GeoTiff
# GE01_La_Spezia_2013_07_18_011651195010_0             16         GeoTiff
# GE01_La_Spezia_2013_07_23_011651202010_0             16         GeoTiff
# GE01_La_Spezia_2017_04_16_011651188010_0             16         GeoTiff
# GE01_La_Spezia_2019_01_03_011651196010_0             16         GeoTiff
# GE01_Toulon 2009_03_23_011651190010_0                16         GeoTiff
# GE01_Toulon 2010_06_08_011651191010_0                16         GeoTiff
# GE01_Toulon 2013_08_20_011651198010_0                16         GeoTiff
# GE01_Toulon 2014_10_16_011651185010_0                16         GeoTiff
# GE01_Toulon 2016_03_26_011651193010_0                16         GeoTiff
# GE01_Toulon 2016_09_21_011651200010_0                16         GeoTiff
# GE01_Toulon 2017_09_05_011651201010_0                16         GeoTiff
# GE01_Toulon 2018_02_13_011651199010_0                16         GeoTiff
# GE01_Toulon 2019_10_07_011651194010_0                16         GeoTiff
# WV02_La_Spezia_2010_08_06_011650744010_0             16         GeoTiff
# WV02_La_Spezia_2011_05_02_011650586010_0             16         GeoTiff
# WV02_La_Spezia_2011_05_10_011650587010_0             16         GeoTiff
# WV02_La_Spezia_2011_10_28_011650745010_0             16         GeoTiff
# WV02_La_Spezia_2012_01_10_011650582010_0             16         GeoTiff
# WV02_La_Spezia_2012_05_17_011650585010_0             16         GeoTiff
# WV02_La_Spezia_2013_10_31_011650588010_0             16         GeoTiff
# WV02_La_Spezia_2013_12_08_011650589010_0             16         GeoTiff
# WV02_La_Spezia_2014_11_20_011650595010_0             16         GeoTiff
# WV02_La_Spezia_2015_01_05_011650746010_0             16         GeoTiff
# WV02_La_Spezia_2015_03_19_011650598010_0             16         GeoTiff
# WV02_La_Spezia_2015_03_19_011650600010_0             16         GeoTiff
# WV02_La_Spezia_2015_04_24_011650748010_0             16         GeoTiff
# WV02_La_Spezia_2015_05_21_011650592010_0             16         GeoTiff
# WV02_La_Spezia_2017_03_10_011650750010_0             16         GeoTiff
# WV02_La_Spezia_2017_07_31_011650593010_0             16         GeoTiff
# WV02_La_Spezia_2018_05_18_011650597010_0             16         GeoTiff
# WV02_La_Spezia_2018_05_29_011650583010_0             16         GeoTiff
# WV02_La_Spezia_2018_07_06_011650749010_0             16         GeoTiff
# WV02_La_Spezia_2019_05_23_011650590010_0             16         GeoTiff
# WV02_La_Spezia_2019_06_03_011650596010_0             16         GeoTiff
# WV02_La_Spezia_2019_10_11_011650594010_0             16         GeoTiff
# WV02_Toulon_2010_11_04_011651051010_0                16         GeoTiff
# WV02_Toulon_2011_05_04_011651058010_0                16         GeoTiff
# WV02_Toulon_2011_12_22_011651063010_0                16         GeoTiff
# WV02_Toulon_2013_03_16_011651062010_0                16         GeoTiff
# WV02_Toulon_2013_04_07_011651056010_0                16         GeoTiff
# WV02_Toulon_2013_04_10_011651050010_0                16         GeoTiff
# WV02_Toulon_2013_10_09_011651061010_0                16         GeoTiff
# WV02_Toulon_2014_04_06_011651052010_0                16         GeoTiff
# WV02_Toulon_2015_11_16_011651049010_0                16         GeoTiff
# WV02_Toulon_2016_03_14_011651064010_0                16         GeoTiff
# WV02_Toulon_2016_03_22_011651057010_0                16         GeoTiff
# WV02_Toulon_2016_03_25_011651060010_0                16         GeoTiff
# WV02_Toulon_2016_03_30_011651053010_0                16         GeoTiff
# WV02_Toulon_2016_09_28_011651048010_0                16         GeoTiff
# WV02_Toulon_2017_08_19_011651059010_0                16         GeoTiff
# WV02_Toulon_2019_07_29_011650877010_0                16         GeoTiff
# WV02_Toulon_2019_08_04_011650878010_0                16         GeoTiff
# ...
# WV02_Toulon_2015_11_16_011651049010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2016_03_14_011651064010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2016_03_22_011651057010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2016_03_25_011651060010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2016_03_30_011651053010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2016_09_28_011651048010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2017_08_19_011651059010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2019_07_29_011650877010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2019_08_04_011650878010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2019_09_11_011650876010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2019_10_16_011650874010_0       RedEdge      NIR     NIR2
# WV02_Toulon_2019_12_15_011650875010_0       RedEdge      NIR     NIR2
# WV03_La_Spezia_2016_01_03_011650743010_0     Yellow  Coastal     NIR2
# WV03_La_Spezia_2018_08_06_011650747010_0     Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2015_04_09_011650880010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2015_07_01_011650884010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2016_01_01_011650881010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2016_02_08_011650888010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2016_04_05_011650879010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2016_04_11_011650882010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2017_07_03_011650887010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2018_10_03_011650886010_0   Yellow  Coastal     NIR2
# WV03_VNIR_Toulon_2019_02_11_011650889010_0   Yellow  Coastal     NIR2
#
#                                                                                  pan_tif_path  \
# GE01_La_Spezia_2009_09_25_011651186010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2011_01_24_011651197010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2012_02_23_011651192010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2012_05_07_011651189010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2012_05_16_011651187010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_07_011651184010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_15_011651183010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_18_011651195010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_23_011651202010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2017_04_16_011651188010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2019_01_03_011651196010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2009_03_23_011651190010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2010_06_08_011651191010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2013_08_20_011651198010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2014_10_16_011651185010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2016_03_26_011651193010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2016_09_21_011651200010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2017_09_05_011651201010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2018_02_13_011651199010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2019_10_07_011651194010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2010_08_06_011650744010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2011_05_02_011650586010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2011_05_10_011650587010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2011_10_28_011650745010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2012_01_10_011650582010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2012_05_17_011650585010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2013_10_31_011650588010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2013_12_08_011650589010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2014_11_20_011650595010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_01_05_011650746010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_03_19_011650598010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_03_19_011650600010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_04_24_011650748010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_05_21_011650592010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2017_03_10_011650750010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2017_07_31_011650593010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2018_05_18_011650597010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2018_05_29_011650583010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2018_07_06_011650749010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2019_05_23_011650590010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2019_06_03_011650596010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2019_10_11_011650594010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2010_11_04_011651051010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2011_05_04_011651058010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2011_12_22_011651063010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_03_16_011651062010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_04_07_011651056010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_04_10_011651050010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_10_09_011651061010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2014_04_06_011651052010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2015_11_16_011651049010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_14_011651064010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_22_011651057010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_25_011651060010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_30_011651053010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_09_28_011651048010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2017_08_19_011651059010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_07_29_011650877010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_08_04_011650878010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_09_11_011650876010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_10_16_011650874010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_12_15_011650875010_0       c:\Users\ono008\master\multispectral-super-res...
# WV03_La_Spezia_2016_01_03_011650743010_0    c:\Users\ono008\master\multispectral-super-res...
# WV03_La_Spezia_2018_08_06_011650747010_0    c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2015_04_09_011650880010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2015_07_01_011650884010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_01_01_011650881010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_02_08_011650888010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_04_05_011650879010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_04_11_011650882010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2017_07_03_011650887010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2018_10_03_011650886010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2019_02_11_011650889010_0  c:\Users\ono008\master\multispectral-super-res...
#
#                                                                                   ms_tif_path
# GE01_La_Spezia_2009_09_25_011651186010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2011_01_24_011651197010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2012_02_23_011651192010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2012_05_07_011651189010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2012_05_16_011651187010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_07_011651184010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_15_011651183010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_18_011651195010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2013_07_23_011651202010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2017_04_16_011651188010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_La_Spezia_2019_01_03_011651196010_0    c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2009_03_23_011651190010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2010_06_08_011651191010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2013_08_20_011651198010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2014_10_16_011651185010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2016_03_26_011651193010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2016_09_21_011651200010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2017_09_05_011651201010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2018_02_13_011651199010_0       c:\Users\ono008\master\multispectral-super-res...
# GE01_Toulon 2019_10_07_011651194010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2010_08_06_011650744010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2011_05_02_011650586010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2011_05_10_011650587010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2011_10_28_011650745010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2012_01_10_011650582010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2012_05_17_011650585010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2013_10_31_011650588010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2013_12_08_011650589010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2014_11_20_011650595010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_01_05_011650746010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_03_19_011650598010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_03_19_011650600010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_04_24_011650748010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2015_05_21_011650592010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2017_03_10_011650750010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2017_07_31_011650593010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2018_05_18_011650597010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2018_05_29_011650583010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2018_07_06_011650749010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2019_05_23_011650590010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2019_06_03_011650596010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_La_Spezia_2019_10_11_011650594010_0    c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2010_11_04_011651051010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2011_05_04_011651058010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2011_12_22_011651063010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_03_16_011651062010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_04_07_011651056010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_04_10_011651050010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2013_10_09_011651061010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2014_04_06_011651052010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2015_11_16_011651049010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_14_011651064010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_22_011651057010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_25_011651060010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_03_30_011651053010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2016_09_28_011651048010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2017_08_19_011651059010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_07_29_011650877010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_08_04_011650878010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_09_11_011650876010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_10_16_011650874010_0       c:\Users\ono008\master\multispectral-super-res...
# WV02_Toulon_2019_12_15_011650875010_0       c:\Users\ono008\master\multispectral-super-res...
# WV03_La_Spezia_2016_01_03_011650743010_0    c:\Users\ono008\master\multispectral-super-res...
# WV03_La_Spezia_2018_08_06_011650747010_0    c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2015_04_09_011650880010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2015_07_01_011650884010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_01_01_011650881010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_02_08_011650888010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_04_05_011650879010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2016_04_11_011650882010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2017_07_03_011650887010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2018_10_03_011650886010_0  c:\Users\ono008\master\multispectral-super-res...
# WV03_VNIR_Toulon_2019_02_11_011650889010_0  c:\Users\ono008\master\multispectral-super-res...

# %% [markdown]
# # Adding geometry to metadata dataframe
#
# Crawls through the data directory looking for polygon vector files (shapefiles, `.shp`) that define the extent of each image. This geometry data is then used to convert the metadata dataframes to `geopandas.GeoDataFrame` objects, a geospatially enabled extension of `pandas.DataFrame`.
#
# The end result is that we can now do spatial queries directly using the dataframe. This will come in handy later when producing imagery tiles that adhere to the spatial boundaries of the imagery.

# %%
def add_EPSG_to_metadata_df(metadata_df):
    # EPSG is a datum/projection code
    metadata_df['EPSG'] = [32631 if utm_zone == '31' 
                           else 32632 if utm_zone == '32' 
                           else None 
                           for utm_zone in metadata_df['mapProjectionZone']]
    return metadata_df

meta = add_EPSG_to_metadata_df(meta)

# %%
def metadata_df_to_geodf(metadata_df, pan_or_ms):
    if pan_or_ms == 'pan':
        pan_or_ms = 'P2AS'
    elif pan_or_ms == 'ms':
        pan_or_ms = 'M2AS'
    else:
        print('pan_or_ms must be either "pan" or "ms"')
        
    data_path = pathlib.Path(DATA_PATH)
    shp_paths = list(data_path.glob(str('**/*' + pan_or_ms + '*PIXEL_SHAPE.shp')))
    metadata_df['geometry'] = None
    for shp_path in shp_paths:
        image_UID = shp_path.parts[2]
        epsg = metadata_df.loc[image_UID, 'EPSG']
        shape = geopandas.read_file(shp_path)
        if shape.crs == None: #4326 is WGS84 geographic projection
            continue
        #print(shape['geometry'])
        shape = shape.to_crs(epsg = epsg)
        metadata_df.at[image_UID, 'geometry'] = shape['geometry'][0]
    
    metadata_geodf = geopandas.GeoDataFrame(metadata_df, geometry = 'geometry')
    return metadata_geodf

meta = metadata_df_to_geodf(meta, 'pan')

# %% [markdown]
# ## Geometry sanity checks

# %%
meta[meta['area_name'] == 'La_Spezia'].boundary.plot()
# Out:
# <AxesSubplot:>

# %%
meta[meta['area_name'] == 'Toulon'].boundary.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Image sizes (m²)
# Name of figure: `image-sizes-distribution`

# %%
rows, cols = 3, 2
fig = plotly.subplots.make_subplots(rows=rows, cols=cols,
                                    subplot_titles=('La Spezia', 
                                                    'Toulon'),
                                    shared_yaxes=True,
                                    shared_xaxes=True,
                                    x_title='image area (km<sup>2)',
                                    y_title='number of images',
                                    vertical_spacing=0.05, 
                                    horizontal_spacing=0.05)

for i, sensor in enumerate(['GE01', 'WV02', 'WV03_VNIR']):
    for j, area in enumerate(['La_Spezia', 'Toulon']):
        m2 = meta[(meta['area_name'] == area) & (meta['sensorVehicle'] == sensor)].area
        km2 = m2 / 10**6
        fig.add_histogram(x=km2,  
                          nbinsx=20,
                          marker=dict(color=px.colors.qualitative.Plotly[0]),
                          bingroup=j,
                          showlegend=False,
                          row=i+1, col=j+1)
    if sensor == 'WV03_VNIR':
        sensor = 'WV03'
    fig.add_annotation(text=sensor, 
                       x=1.01, y=0.11+(rows-i-1)*0.38,
                       xref='paper', yref='paper',
                       xanchor='left',
                       showarrow=False) 
fig.update_layout(autosize=True,
                  title='Distribution of image sizes by area and satellite', title_x=0.5,
                  width=700, height=500
                 )
fig.show()
# Out:
# <div>                            <div id="7f0fcec4-3160-4d65-84c4-4f44096ca224" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f0fcec4-3160-4d65-84c4-4f44096ca224")) {                    Plotly.newPlot(                        "7f0fcec4-3160-4d65-84c4-4f44096ca224",                        [{"bingroup": "0", "marker": {"color": "#636EFA"}, "nbinsx": 20, "showlegend": false, "type": "histogram", "x": [22.153449136971187, 23.524764589582965, 23.520230483869803, 7.879835288607815, 8.64061364994323, 9.574120928740932, 8.500804834827617, 9.37596853812832, 12.921213114821807, 23.53512534312001, 23.487055394431533], "xaxis": "x", "yaxis": "y"}, {"bingroup": "1", "marker": {"color": "#636EFA"}, "nbinsx": 20, "showlegend": false, "type": "histogram", "x": [13.72468322048592, 13.723262157107383, 13.728116772547272, 13.722910592926528, 7.7111063648347375, 13.73186227496702, 13.723875235036989, 13.725489407539289, 13.733671853095773], "xaxis": "x2", "yaxis": "y2"}, {"bingroup": "0", "marker": {"color": "#636EFA"}, "nbinsx": 20, "showlegend": false, "type": "histogram", "x": [23.521343994758514, 6.612233182603931, 5.229487998840909, 23.521343994758514, 23.521343994758514, 23.521054105627332, 22.520150708921726, 23.521343994758514, 23.521343994758514, 23.521343994758514, 23.521343994758514, 23.521343994758514, 23.528554323008734, 23.521343994758514, 23.521343994758514, 23.523513342197802, 19.64223059181294, 20.852588628496406, 23.521343994758514, 23.521343994758514, 23.517922128783244, 19.290831995696934], "xaxis": "x3", "yaxis": "y3"}, {"bingroup": "1", "marker": {"color": "#636EFA"}, "nbinsx": 20, "showlegend": false, "type": "histogram", "x": [13.724940103218547, 13.722464707287111, 13.725836820047215, 13.724940103218547, 13.724339021930266, 13.724940103218547, 13.724940103218547, 13.724940103218547, 13.724940103218547, 13.724940103218547, 13.724940103218547, 13.165338104232738, 13.724940103218547, 13.724940103218547, 13.728573517443873, 13.724940103218547, 13.724940103218547, 13.724940103218547, 13.724940103218547, 13.724940103218547], "xaxis": "x4", "yaxis": "y4"}, {"bingroup": "0", "marker": {"color": "#636EFA"}, "nbinsx": 20, "showlegend": false, "type": "histogram", "x": [21.568293799503525, 20.42407738086622], "xaxis": "x5", "yaxis": "y5"}, {"bingroup": "1", "marker": {"color": "#636EFA"}, "nbinsx": 20, "showlegend": false, "type": "histogram", "x": [13.732149898610388, 13.728735919659323, 13.723995051715601, 13.72664811289039, 13.727042371273185, 13.727076070383523, 13.72851835475904, 13.727821496065992, 13.731790947216068], "xaxis": "x6", "yaxis": "y6"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "La Spezia", "x": 0.2375, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Toulon", "x": 0.7625, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "image area (km<sup>2)", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 0, "yanchor": "top", "yref": "paper", "yshift": -30}, {"font": {"size": 16}, "showarrow": false, "text": "number of images", "textangle": -90, "x": 0, "xanchor": "right", "xref": "paper", "xshift": -40, "y": 0.5, "yanchor": "middle", "yref": "paper"}, {"showarrow": false, "text": "GE01", "x": 1.01, "xanchor": "left", "xref": "paper", "y": 0.87, "yref": "paper"}, {"showarrow": false, "text": "WV02", "x": 1.01, "xanchor": "left", "xref": "paper", "y": 0.49, "yref": "paper"}, {"showarrow": false, "text": "WV03", "x": 1.01, "xanchor": "left", "xref": "paper", "y": 0.11, "yref": "paper"}], "autosize": true, "height": 500, "template": {"data": {"bar": [{"error_x":  ...

# %% [markdown]
# # Clouds

# %%
CLOUDS_PATH = 'data/toulon-laspezia-clouds'

clouds_laspezia = geopandas.read_file(pathlib.Path(CLOUDS_PATH, 'laspezia-clouds.shp'))
clouds_toulon = geopandas.read_file(pathlib.Path(CLOUDS_PATH, 'toulon-clouds.shp'))

# %%
def add_area_to_metadata_gdf(metadata_gdf):
    metadata_gdf['area_m2'] = metadata_gdf['geometry'].area.astype('float32')
    return metadata_gdf

meta = add_area_to_metadata_gdf(meta)

# %%
def add_clouds_area_to_metadata_gdf(metadata_gdf, clouds_gdf):
    for image_UID in clouds_gdf['image_id'].unique():
        clouds_sum = 0.0
        for polygon in clouds_gdf.loc[clouds_gdf['image_id'] == image_UID, 'geometry']:
            #print(type(polygon.area))
            clouds_sum += polygon.area
        metadata_gdf.at[image_UID, 'clouds_area_m2'] = clouds_sum
        
    metadata_gdf = metadata_gdf.astype({'clouds_area_m2': 'float32'})
    metadata_gdf['clouds_area_m2'].fillna(0.0, inplace = True)
    
    return metadata_gdf

meta = add_clouds_area_to_metadata_gdf(meta, clouds_laspezia)
meta = add_clouds_area_to_metadata_gdf(meta, clouds_toulon)

# %%
def add_cloud_ratio_to_metadata_gdf(metadata_gdf):
    metadata_gdf['cloud_ratio'] = metadata_gdf['clouds_area_m2'] / metadata_gdf['area_m2']
    return metadata_gdf

meta = add_cloud_ratio_to_metadata_gdf(meta)

meta['cloud_ratio'].hist(bins = 20)

# %%
meta

# %% [markdown]
# ## Area and clouds statistics

# %%
def add_max_image_size_to_metadata_gdf(metadata_gdf):
    for area_name in metadata_gdf['area_name'].unique():
        
        # Find the max area for each location
        max_area_m2 = metadata_gdf.loc[metadata_gdf['area_name'] == area_name, 'area_m2'].max()
        
        # Add this to a column in the gdf
        metadata_gdf.loc[metadata_gdf['area_name'] == area_name, 'area_m2_max'] = max_area_m2
        #['area_m2_max'] = max_area_m2
    
    # Calculate an "area_ratio", a measure of how large an image is compared to the max sized image
    # Low number means that the image is small and only cover a minor part of the area
    metadata_gdf['area_ratio'] = metadata_gdf['area_m2']/metadata_gdf['area_m2_max']

    return metadata_gdf

meta = add_max_image_size_to_metadata_gdf(meta)

# %%
#meta['area_ratio'].sort_values()

# %%
def train_val_test_split(metadata_gdf, 
                         area_ratio_treshold, 
                         cloud_ratio_treshold, 
                         train_val_test_split,
                         seed = 18):
    df = metadata_gdf
    df['train_val_test'] = None
    np.random.seed(seed)
    
    # WV03
    print('Starting with', len(metadata_gdf), 'images')
    print('Assigning all WV03 to training set...')
    # There are not many of these and they are not well distributed between the areas so no effort will
    # be done on evaluating on these images.
    df.loc[df['sensorVehicle'] == 'WV03_VNIR', 'train_val_test'] = 'train'
    print('Number of images left to assign:', 
          len(df[df['train_val_test'].isnull()]))
    
    # Randomly assign GE01 to either val or test sets
    # These will not be used for training, but serve as a measure of how well the model can perform on 
    # a different sensor
    print('Randomly assigning GE01 images to val or test sets')
    for area_name in df['area_name'].unique():
        n = len(df[(df['sensorVehicle'] == 'GE01') & (df['area_name'] == area_name)])
        partition =  ['val'] * int(n/2) + ['test'] * (n - int(n/2))
        np.random.shuffle(partition)
        df.loc[(df['sensorVehicle'] == 'GE01') & (df['area_name'] == area_name), 'train_val_test'] = partition        
    print('Number of images left to assign:', 
          len(df[df['train_val_test'].isnull()]))

    # WV02:
    print('Assigning very cloudy WV02 images to training set')
    # Assign images with cloud ratio higher than threshold to training set
    # In other words: Remove very cloudy images from validation and test set
    df.loc[(df['cloud_ratio'] > cloud_ratio_treshold) & (df['sensorVehicle'] == 'WV02'), 
           'train_val_test'] = 'train'
    print('Number of images left to assign:', 
          len(df[df['train_val_test'].isnull()]))
    
    print('Assigning very small WV02 images to training set')
    # We want to make sure that val and test sets are representative and not dominated by
    # small images that only cover parts of the overall image area
    df.loc[(df['area_ratio'] < area_ratio_treshold) & (df['sensorVehicle'] == 'WV02'), 
           'train_val_test'] = 'train'
    print('Number of images left to assign:', 
          len(df[df['train_val_test'].isnull()]))


    print('Randomly assigning remaining WV02 images to train, val or test sets according to', 
         train_val_test_split, 'split')
    for area_name in df['area_name'].unique():
        selection = (df['sensorVehicle'] == 'WV02') & (df['train_val_test'].isnull()) & (df['area_name'] == area_name)
        n = len(df[selection])
        n_val = int(n*train_val_test_split[1])
        n_test = int(n*train_val_test_split[2])
        n_train = n - (n_val + n_test)
        partition =  ['val'] * n_val + ['test'] * n_test + ['train'] * n_train
        np.random.shuffle(partition)
        df.loc[selection, 'train_val_test'] = partition
    print('Number of images left to assign:', 
          len(df[df['train_val_test'].isnull()]))
    print('Finished')
    return df
    

# cloud_ratio_treshold set to 1 means that clouds are not used as 

meta = train_val_test_split(meta, 
                            area_ratio_treshold = 0.5, 
                            cloud_ratio_treshold = 1, 
                            train_val_test_split = [0.5, 0.25, 0.25],
                            seed = 18)

# %%
meta['train_val_test']

# %% [markdown]
# # Distribution of images across the train/val/test partition

# %% [markdown]
# ## Contingency tables

# %%
pd.crosstab(meta['train_val_test'], meta['area_name'], margins=True)

# %%
pd.crosstab(meta['train_val_test'], meta['sensorVehicle'], margins=True)

# %%
pd.crosstab(meta['area_name'], meta['sensorVehicle'], margins=True)

# %% [markdown]
# ## Histograms

# %%
def hist_by_partition(meta, sensor_filter):
    # Convert string to list if only one sensor_filter is given
    if type(sensor_filter) == str:
        sensor_filter = [sensor_filter]
        
    train_val_test = ['train', 'val', 'test']
    colors = ['green', 'blue', 'orange']
    
    fig, axs = plt.subplots(1, 3, figsize=(15,4.5))
    
    axs[0].hist([meta.loc[(meta['train_val_test'] == x) & (meta['sensorVehicle'].isin(sensor_filter)), 
                             'cloud_ratio'] for x in train_val_test], 
                   color = colors)
    axs[0].set_title('Cloud cover')
    axs[0].legend(train_val_test)
    
    axs[1].hist([meta.loc[(meta['train_val_test'] == x) & (meta['sensorVehicle'].isin(sensor_filter)), 
                             'area_ratio'] for x in train_val_test], 
                    color = colors)
    axs[1].set_title('Image size (proportion of full size image)')
    axs[1].legend(train_val_test)
    
    axs[2].hist([meta.loc[(meta['train_val_test'] == x) & (meta['sensorVehicle'].isin(sensor_filter)), 
                             'offNadirAngle'] for x in train_val_test], 
                    color = colors)
    axs[2].set_title('Off-Nadir angle (0 is image taken directly from above)')
    axs[2].legend(train_val_test)
    
    fig.suptitle(str('Training/Validation/Test partition plot for sensor(s) ' + str(sensor_filter)))

hist_by_partition(meta, sensor_filter = ['WV02', 'GE01', 'WV03_VNIR'])
hist_by_partition(meta, sensor_filter = 'GE01')
hist_by_partition(meta, sensor_filter = 'WV03_VNIR')
hist_by_partition(meta, sensor_filter = 'WV02')

# %% [markdown]
# # Save metadata as .csv and .pickle
#
# .csv file for simplicity and interoperability and .pickle to also include geospatial information.

# %%
#meta.to_csv('metadata_df.csv')

#with open('metadata_df.pickle', 'wb') as file:
#    pickle.dump(meta, file)
